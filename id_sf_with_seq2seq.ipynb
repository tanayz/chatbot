# %% [markdown]
# * Derived from the medium article
# https://towardsdatascience.com/natural-language-understanding-with-sequence-to-sequence-models-e87d41ad258b

# %%
import pickle
import os
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.layers import Dropout,LSTM,Embedding,Dense
from tensorflow.keras import Input,Model
from nltk.translate.bleu_score import corpus_bleu
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
DATA_DIR="data/"

# load Pickle file 
def load_ds(fname=os.path.join(DATA_DIR,'/atis.train.pkl'), verbose=True):
    with open(fname, 'rb') as stream:
        ds,dicts = pickle.load(stream)
    if verbose:
      print('Done  loading: ', fname)
      print('      samples: {:4d}'.format(len(ds['query'])))
      print('   vocab_size: {:4d}'.format(len(dicts['token_ids'])))
      print('   slot count: {:4d}'.format(len(dicts['slot_ids'])))
      print(' intent count: {:4d}'.format(len(dicts['intent_ids'])))
    return ds,dicts
  
# convert Pickle file to arrays
def load_atis(filename, add_start_end_token=False, verbose=True):
    train_ds, dicts = load_ds(os.path.join(DATA_DIR,filename), verbose)
    t2i, s2i, in2i = map(dicts.get, ['token_ids', 'slot_ids','intent_ids'])
    i2t, i2s, i2in = map(lambda d: {d[k]:k for k in d.keys()}, [t2i,s2i,in2i])
    query, slots, intent =  map(train_ds.get, ['query', 'slot_labels', 'intent_labels'])

    if add_start_end_token:
        i2s[178] = 'BOS'
        i2s[179] = 'EOS'
        s2i['BOS'] = 178
        s2i['EOS'] = 179

    input_tensor = []
    target_tensor = []
    query_data = []
    intent_data = []
    slot_data = []
    to_show = np.random.randint(0, len(query)-1, 5)
    for i in range(len(query)):
        input_tensor.append(query[i])
        slot_text = []
        slot_vector = []
        for j in range(len(query[i])):
            slot_text.append(i2s[slots[i][j]])
            slot_vector.append(slots[i][j])
        if add_start_end_token:
            slot_text[0] = 'BOS'
            slot_vector[0] = 178
            slot_text[-1] = 'EOS'
            slot_vector[-1]= 179
        target_tensor.append(slot_vector)
        q = ' '.join(map(i2t.get, query[i]))
        query_data.append(q.replace('BOS', '').replace('EOS',''))
        intent_data.append(i2in[intent[i][0]])
        slot = ' '.join(slot_text)
        slot_data.append(slot[1:-1])
        if i in to_show and verbose:
          print('Query text:', q)
          print('Query vector: ', query[i])
          print('Intent label: ', i2in[intent[i][0]])
          print('Slot text: ', slot)
          print('Slot vector: ', slot_vector)
          print('*'*74)
    query_data = np.array(query_data)
    intent_data = np.array(intent_data)
    slot_data = np.array(slot_data)
    intent_data_label = np.array(intent).flatten()
    return t2i, s2i, in2i, i2t, i2s, i2in, input_tensor, target_tensor,query_data, intent_data, intent_data_label, slot_data

# %%
# load ATIS training dataset
t2i_train, s2i_train, in2i_train, i2t_train, i2s_train, i2in_train, \
input_tensor_train, target_tensor_train, \
query_data_train, intent_data_train, intent_data_label_train, slot_data_train = load_atis('atis.train.pkl')

# load ATIS testing dataset
t2i_test, s2i_test, in2i_test, i2t_test, i2s_test, i2in_test, \
input_tensor_test, target_tensor_test, \
query_data_test, intent_data_test, intent_data_label_test, slot_data_test = load_atis('atis.test.pkl')
# Out:
# Done  loading:  data/atis.train.pkl
#       samples: 4978
#    vocab_size:  943
#    slot count:  129
#  intent count:   26
# Query text: BOS what flights leave from phoenix to nashville on american airlines EOS
# Query vector:  [178 916 429 537 444 681 851 614 654 212 200 179]
# Intent label:  flight
# Slot text:  O O O O O B-fromloc.city_name O B-toloc.city_name O B-airline_name I-airline_name O
# Slot vector:  [128, 128, 128, 128, 128, 48, 128, 78, 128, 2, 83, 128]
# **************************************************************************
# Query text: BOS show me the flights from san francisco to boston EOS
# Query vector:  [178 770 581 827 429 444 739 440 851 266 179]
# Intent label:  flight
# Slot text:  O O O O O O B-fromloc.city_name I-fromloc.city_name O B-toloc.city_name O
# Slot vector:  [128, 128, 128, 128, 128, 128, 48, 110, 128, 78, 128]
# **************************************************************************
# Query text: BOS now get me from pittsburgh to denver EOS
# Query vector:  [178 637 447 581 444 682 851 351 179]
# Intent label:  flight
# Slot text:  O O O O O B-fromloc.city_name O B-toloc.city_name O
# Slot vector:  [128, 128, 128, 128, 128, 48, 128, 78, 128]
# **************************************************************************
# Query text: BOS i 'd like information on boston to washington EOS
# Query vector:  [178 479   0 545 492 654 266 851 905 179]
# Intent label:  flight
# Slot text:  O O O O O O B-fromloc.city_name O B-toloc.city_name O
# Slot vector:  [128, 128, 128, 128, 128, 128, 48, 128, 78, 128]
# **************************************************************************
# Query text: BOS what 's the cheapest flight from pittsburgh to san francisco on friday EOS
# Query vector:  [178 916   5 827 296 428 444 682 851 739 440 654 441 179]
# Intent label:  flight
# Slot text:  O O O O B-cost_relative O O B-fromloc.city_name O B-toloc.city_name I-toloc.city_name O B-depart_date.day_name O
# Slot vector:  [128, 128, 128, 128, 21, 128, 128, 48, 128, 78, 125, 128, 26, 128]
# **************************************************************************
# Done  loading:  data/atis.test.pkl
#       samples:  893
#    vocab_size:  943
#    slot count:  129
#  intent count:   26
# Query text: BOS find a flight from memphis to tacoma dinner EOS
# Query vector:  [178 423 180 428 444 587 851 810 367 179]
# Intent label:  flight
# Slot text:  O O O O O B-fromloc.city_name O B-toloc.city_name B-meal_description O
# Slot vector:  [128, 128, 128, 128, 128, 48, 128, 78, 53, 128]
# **************************************************************************
# Query text: BOS list flights from phoenix arizona to ontario california wednesday EOS
# Query vector:  [178 549 429 444 681 230 851 658 279 908 179]
# Intent label:  flight
# Slot text:  O O O O B-fromloc.city_name B-fromloc.state_name O B-toloc.city_name B-toloc.state_name B-depart_date.day_name O
# Slot vector:  [128, 128, 128, 128, 48, 50, 128, 78, 81, 26, 128]
# **************************************************************************
# Query text: BOS cleveland to kansas city arrive monday before 3 pm EOS
# Query vector:  [178 304 851 511 301 236 601 253  87 689 179]
# Intent label:  flight
# Slot text:  O B-fromloc.city_name O B-toloc.city_name I-toloc.city_name O B-arrive_date.day_name B-arrive_time.time_relative B-arrive_time.time I-arrive_time.time O
# Slot vector:  [128, 48, 128, 78, 125, 128, 6, 15, 14, 89, 128]
# **************************************************************************
# Query text: BOS list airports EOS
# Query vector:  [178 549 204 179]
# Intent label:  airport
# Slot text:  O O O O
# Slot vector:  [128, 128, 128, 128]
# **************************************************************************
# Query text: BOS i want a flight from toronto to san diego EOS
# Query vector:  [178 479 902 180 428 444 856 851 739 364 179]
# Intent label:  flight
# Slot text:  O O O O O O B-fromloc.city_name O B-toloc.city_name I-toloc.city_name O
# Slot vector:  [128, 128, 128, 128, 128, 128, 48, 128, 78, 125, 128]
# **************************************************************************

# %%
pd.set_option('display.max_colwidth', -1)
df = pd.DataFrame({'query': query_data_train, 'intent': intent_data_train, 'slot filling': slot_data_train})

df_small = pd.DataFrame(columns=['query','intent','slot filling'])
j = 0
for i in df.intent.unique():
  df_small.loc[j] = df[df.intent==i].iloc[0]
  j = j+1
  
df_small
# Out:
#                                                                                                                                                                      query  \
# 0    i want to fly from boston at 838 am and arrive in denver at 1110 in the morning
# 1    what is the arrival time in san francisco for the 755 am flight leaving washington
# 2    cheapest airfare from tacoma to orlando
# 3    what kind of aircraft is used on a flight from cleveland to dallas
# 4    what kind of ground transportation is available in denver
# 5    what 's the airport at orlando
# 6    which airline serves denver pittsburgh and atlanta
# 7    how far is it from orlando airport to orlando
# 8    what is fare code h
# 9    how much does the limousine service cost within pittsburgh
# 10   please tell me how many nonstop flights there are from boston to atlanta
# 11   what city is the airport mco in
# 12   flight numbers from columbus to minneapolis tomorrow
# 13   how many seats in a 100
# 14   give me the flights and fares on december twenty seventh from indianapolis to orlando
# 15   show me all meals on flights from atlanta to washington
# 16   what are the air restrictions on flights from pittsburgh to atlanta for the airfare of 416 dollars
# 17   airline and flight number from columbus to minneapolis
# 18   what ground transportation is available from the pittsburgh airport to downtown and how much does it cost
# 19   show me the costs and times for flights from san francisco to atlanta
# 20   show me the cheapest fare in the database
# 21   i want to fly from detroit to st. petersburg on northwest airlines and leave around 9 am tell me what aircraft are used by this flight and tell me the flight number
#
#                         intent  \
# 0   flight
# 1   flight_time
# 2   airfare
# 3   aircraft
# 4   ground_service
# 5   airport
# 6   airline
# 7   distance
# 8   abbreviation
# 9   ground_fare
# 10  quantity
# 11  city
# 12  flight_no
# 13  capacity
# 14  flight+airfare
# 15  meal
# 16  restriction
# 17  airline+flight_no
# 18  ground_service+ground_fare
# 19  airfare+flight_time
# 20  cheapest
# 21  aircraft+flight+flight_no
#
#                                                                                                                                                                                                  slot filling
# 0    O O O O O B-fromloc.city_name O B-depart_time.time I-depart_time.time O O O B-toloc.city_name O B-arrive_time.time O O B-arrive_time.period_of_day
# 1    O O O B-flight_time I-flight_time O B-fromloc.city_name I-fromloc.city_name O O B-depart_time.time I-depart_time.time O O B-fromloc.city_name
# 2    B-cost_relative O O B-fromloc.city_name O B-toloc.city_name
# 3    O O O O O O O O O O B-fromloc.city_name O B-toloc.city_name
# 4    O O O O O O O O B-city_name
# 5    O O O O O B-city_name
# 6    O O O B-fromloc.city_name B-fromloc.city_name O B-fromloc.city_name
# 7    O O O O O B-fromloc.airport_name I-fromloc.airport_name O B-toloc.city_name
# 8    O O O O B-fare_basis_code
# 9    O O O O B-transport_type O O O B-city_name
# 10   O O O O O B-flight_stop O O O O B-fromloc.city_name O B-toloc.city_name
# 11   O O O O O B-fromloc.airport_code O
# 12   O O O B-fromloc.city_name O B-toloc.city_name B-depart_date.today_relative
# 13   O O O O O B-aircraft_code
# 14   O O O O O O O B-depart_date.month_name B-depart_date.day_number I-depart_date.day_number O B-fromloc.city_name O B-toloc.city_name
# 15   O O O B-meal O O O B-fromloc.city_name O B-toloc.city_name
# 16   O O O O O O O O B-fromloc.city_name O B-toloc.city_name O O O O B-fare_amount I-fare_amount
# 17   O O O O O B-fromloc.city_name O B-toloc.city_name
# 18   O O O O O O O B-fromloc.airport_name I-fromloc.airport_name O O O O O O O O
# 19   O O O O O B-flight_time O O O B-fromloc.city_name I-fromloc.city_name O B-toloc.city_name
# 20   O O O B-cost_relative O O O O
# 21   O O O O O B-fromloc.city_name O B-toloc.city_name I-toloc.city_name O B-airline_name I-airline_name O O B-depart_time.time_relative B-depart_time.time I-depart_time.time O O O O O O O O O O O O O O O

# %%
i2s_train_values = list(i2s_train.values())
df3 = pd.DataFrame()
for i in range(7):
  df3[str(i)] = i2s_train_values[i*15:(i+1)*15]
df3
# Out:
#                                0                             1  \
# 0   B-aircraft_code               B-arrive_time.time_relative
# 1   B-airline_code                B-booking_class
# 2   B-airline_name                B-city_name
# 3   B-airport_code                B-class_type
# 4   B-airport_name                B-compartment
# 5   B-arrive_date.date_relative   B-connect
# 6   B-arrive_date.day_name        B-cost_relative
# 7   B-arrive_date.day_number      B-day_name
# 8   B-arrive_date.month_name      B-day_number
# 9   B-arrive_date.today_relative  B-days_code
# 10  B-arrive_time.end_time        B-depart_date.date_relative
# 11  B-arrive_time.period_mod      B-depart_date.day_name
# 12  B-arrive_time.period_of_day   B-depart_date.day_number
# 13  B-arrive_time.start_time      B-depart_date.month_name
# 14  B-arrive_time.time            B-depart_date.today_relative
#
#                               2                            3  \
# 0   B-depart_date.year           B-flight_time
# 1   B-depart_time.end_time       B-fromloc.airport_code
# 2   B-depart_time.period_mod     B-fromloc.airport_name
# 3   B-depart_time.period_of_day  B-fromloc.city_name
# 4   B-depart_time.start_time     B-fromloc.state_code
# 5   B-depart_time.time           B-fromloc.state_name
# 6   B-depart_time.time_relative  B-meal
# 7   B-economy                    B-meal_code
# 8   B-fare_amount                B-meal_description
# 9   B-fare_basis_code            B-mod
# 10  B-flight                     B-month_name
# 11  B-flight_days                B-or
# 12  B-flight_mod                 B-period_of_day
# 13  B-flight_number              B-restriction_code
# 14  B-flight_stop                B-return_date.date_relative
#
#                                4                            5  \
# 0   B-return_date.day_name        B-today_relative
# 1   B-return_date.day_number      B-toloc.airport_code
# 2   B-return_date.month_name      B-toloc.airport_name
# 3   B-return_date.today_relative  B-toloc.city_name
# 4   B-return_time.period_mod      B-toloc.country_name
# 5   B-return_time.period_of_day   B-toloc.state_code
# 6   B-round_trip                  B-toloc.state_name
# 7   B-state_code                  B-transport_type
# 8   B-state_name                  I-airline_name
# 9   B-stoploc.airport_code        I-airport_name
# 10  B-stoploc.airport_name        I-arrive_date.day_number
# 11  B-stoploc.city_name           I-arrive_time.end_time
# 12  B-stoploc.state_code          I-arrive_time.period_of_day
# 13  B-time                        I-arrive_time.start_time
# 14  B-time_relative               I-arrive_time.time
#
#                                6
# 0   I-arrive_time.time_relative
# 1   I-city_name
# 2   I-class_type
# 3   I-cost_relative
# 4   I-depart_date.day_name
# 5   I-depart_date.day_number
# 6   I-depart_date.today_relative
# 7   I-depart_time.end_time
# 8   I-depart_time.period_of_day
# 9   I-depart_time.start_time
# 10  I-depart_time.time
# 11  I-depart_time.time_relative
# 12  I-economy
# 13  I-fare_amount
# 14  I-fare_basis_code

# %%
def max_length(tensor):
    return max(len(t) for t in tensor)

# Helper function to pad the query tensor and slot (target) tensor to the same length. 
# Also creates a tensor for teacher forcing.
def create_tensors(input_tensor, target_tensor, nb_sample=9999999, max_len=0):
    len_input, len_target  = max_length(input_tensor), max_length(target_tensor)
    len_input = max(len_input,max_len)
    len_target = max(len_target,max_len)
    

    # Padding the input and output tensor to the maximum length
    input_data = tf.keras.preprocessing.sequence.pad_sequences(input_tensor, 
                                                                 maxlen=len_input,
                                                                 padding='post')

    teacher_data = tf.keras.preprocessing.sequence.pad_sequences(target_tensor, 
                                                                  maxlen=len_target , 
                                                                  padding='post')
    
    target_data = [[teacher_data[n][i+1] for i in range(len(teacher_data[n])-1)] for n in range(len(teacher_data))]
    target_data = tf.keras.preprocessing.sequence.pad_sequences(target_data, maxlen=len_target, padding="post")
    target_data = target_data.reshape((target_data.shape[0], target_data.shape[1], 1))
    
    nb = len(input_data)
    p = np.random.permutation(nb)
    input_data = input_data[p]
    teacher_data = teacher_data[p]
    target_data = target_data[p]

    return input_data[:min(nb_sample, nb)], teacher_data[:min(nb_sample, nb)], target_data[:min(nb_sample, nb)],len_input, len_target

# %%
           
input_data_train, teacher_data_train, target_data_train,len_input_train, len_target_train  = create_tensors(input_tensor_train, target_tensor_train)
input_data_test, teacher_data_test, target_data_test,len_input_test, len_target_test  = create_tensors(input_tensor_test, target_tensor_test, max_len=len_input_train)

# %%
def get_vocab_size(t2i_train, t2i_test, s2i_train, s2i_test):
    vocab_in_size = len({**t2i_train, **t2i_test})
    vocab_out_size = len({**s2i_train, **s2i_test})
    return vocab_in_size, vocab_out_size
  
vocab_in_size, vocab_out_size = get_vocab_size(t2i_train, t2i_test, s2i_train, s2i_test)
vocab_in_size, vocab_out_size
# Out:
# (943, 129)

# %%
BUFFER_SIZE = len(input_data_train)
BATCH_SIZE = 64
N_BATCH = BUFFER_SIZE//BATCH_SIZE
embedding_dim = 256
units = 1024

# Create the Encoder layers first.
encoder_inputs = Input(shape=(len_input_train,))
encoder_emb = Embedding(input_dim=vocab_in_size, output_dim=embedding_dim)
encoder_lstm = LSTM(units=units, return_sequences=True, return_state=True)
encoder_outputs, state_h, state_c = encoder_lstm(encoder_emb(encoder_inputs))
encoder_states = [state_h, state_c]

# Now create the Decoder layers.
decoder_inputs = Input(shape=(None,))
decoder_emb = Embedding(input_dim=vocab_out_size, output_dim=embedding_dim)
decoder_lstm = LSTM(units=units, return_sequences=True, return_state=True)
decoder_lstm_out, _, _ = decoder_lstm(decoder_emb(decoder_inputs), initial_state=encoder_states)
# Two dense layers to improve inference capabilities.
decoder_d1 = Dense(units, activation="relu")
decoder_d2 = Dense(vocab_out_size, activation="softmax")
# Drop-out is added in the dense layers to help mitigate overfitting in this part of the model.
decoder_out = decoder_d2(Dropout(rate=.4)(decoder_d1(Dropout(rate=.4)(decoder_lstm_out))))

# Finally, create a training model which combines the encoder and the decoder.
# Note that this model has three inputs:
#  encoder_inputs=[batch,encoded_words] from input (query)
#  decoder_inputs=[batch,encoded_words] from output (slots). This is the "teacher tensor".
#  decoder_out=[batch,encoded_words] from output (slots). This is the "target tensor".
model = Model([encoder_inputs, decoder_inputs], decoder_out)
# Use sparse_categorical_crossentropy so we don't have to expand decoder_out into a massive one-hot array.
model.compile(optimizer=tf.keras.optimizers.Adam(), loss="sparse_categorical_crossentropy", metrics=['sparse_categorical_accuracy'])

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 48)]         0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, None)]       0
# __________________________________________________________________________________________________
# embedding (Embedding)           (None, 48, 256)      241408      input_1[0][0]
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, None, 256)    33024       input_2[0][0]
# __________________________________________________________________________________________________
# lstm (LSTM)                     [(None, 48, 1024), ( 5246976     embedding[0][0]
# __________________________________________________________________________________________________
# lstm_1 (LSTM)                   [(None, None, 1024), 5246976     embedding_1[0][0]
#                                                                  lstm[0][1]
#                                                                  lstm[0][2]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, None, 1024)   0           lstm_1[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, None, 1024)   1049600     dropout_1[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, None, 1024)   0           dense[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, None, 129)    132225      dropout[0][0]
# ==================================================================================================
# Total params: 11,950,209
# Trainable params: 11,950,209
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# Directory where the checkpoints will be saved
checkpoint_dir = './checkpoints'
# Name of the checkpoint files
checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt_{epoch}")

checkpoint_callback=tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_prefix,
    save_weights_only=True,
    monitor='val_sparse_categorical_accuracy',
    mode='max',
    save_best_only=True
)

# %%
epochs = 50
history = model.fit([input_data_train, teacher_data_train], target_data_train,
                 batch_size=BATCH_SIZE,
                 epochs=epochs,
                 validation_data=([input_data_test, teacher_data_test], target_data_test),
                 callbacks=[checkpoint_callback])
# Out:
# Train on 4978 samples, validate on 893 samples
# Epoch 1/50
# 4978/4978 [==============================] - 26s 5ms/sample - loss: 1.0898 - sparse_categorical_accuracy: 0.8220 - val_loss: 0.4798 - val_sparse_categorical_accuracy: 0.8864
# Epoch 2/50
# 4978/4978 [==============================] - 17s 3ms/sample - loss: 0.4625 - sparse_categorical_accuracy: 0.8895 - val_loss: 0.4183 - val_sparse_categorical_accuracy: 0.8969
# Epoch 3/50
# 4978/4978 [==============================] - 17s 3ms/sample - loss: 0.3948 - sparse_categorical_accuracy: 0.9063 - val_loss: 0.3354 - val_sparse_categorical_accuracy: 0.9181
# Epoch 4/50
# 4978/4978 [==============================] - 17s 3ms/sample - loss: 0.3435 - sparse_categorical_accuracy: 0.9180 - val_loss: 0.3085 - val_sparse_categorical_accuracy: 0.9228
# Epoch 5/50
# 4978/4978 [==============================] - 17s 3ms/sample - loss: 0.3172 - sparse_categorical_accuracy: 0.9213 - val_loss: 0.2886 - val_sparse_categorical_accuracy: 0.9273
# Epoch 6/50
# 4978/4978 [==============================] - 17s 3ms/sample - loss: 0.2998 - sparse_categorical_accuracy: 0.9251 - val_loss: 0.2795 - val_sparse_categorical_accuracy: 0.9298
# Epoch 7/50
# 4978/4978 [==============================] - 17s 3ms/sample - loss: 0.2900 - sparse_categorical_accuracy: 0.9269 - val_loss: 0.2744 - val_sparse_categorical_accuracy: 0.9301
# Epoch 8/50
# 4978/4978 [==============================] - 17s 3ms/sample - loss: 0.2837 - sparse_categorical_accuracy: 0.9283 - val_loss: 0.2686 - val_sparse_categorical_accuracy: 0.9311
# Epoch 9/50
# 4978/4978 [==============================] - 17s 3ms/sample - loss: 0.2773 - sparse_categorical_accuracy: 0.9293 - val_loss: 0.2641 - val_sparse_categorical_accuracy: 0.9316
# Epoch 10/50
# 4978/4978 [==============================] - 17s 3ms/sample - loss: 0.2725 - sparse_categorical_accuracy: 0.9299 - val_loss: 0.2633 - val_sparse_categorical_accuracy: 0.9320
# Epoch 11/50
# 4978/4978 [==============================] - 17s 3ms/sample - loss: 0.2691 - sparse_categorical_accuracy: 0.9303 - val_loss: 0.2579 - val_sparse_categorical_accuracy: 0.9337
# Epoch 12/50
# 4978/4978 [==============================] - 17s 3ms/sample - loss: 0.2503 - sparse_categorical_accuracy: 0.9369 - val_loss: 0.2259 - val_sparse_categorical_accuracy: 0.9442
# Epoch 13/50
# 4978/4978 [==============================] - 17s 3ms/sample - loss: 0.2242 - sparse_categorical_accuracy: 0.9449 - val_loss: 0.2058 - val_sparse_categorical_accuracy: 0.9489
# Epoch 14/50
# 4978/4978 [==============================] - 17s 3ms/sample - loss: 0.1979 - sparse_categorical_accuracy: 0.9511 - val_loss: 0.1861 - val_sparse_categorical_accuracy: 0.9519
# Epoch 15/50
# 4978/4978 [==============================] - 17s 3ms/sample - loss: 0.1781 - sparse_categorical_accuracy: 0.9543 - val_loss: 0.1712 - val_sparse_categorical_accuracy: 0.9558
# Epoch 16/50
# 4978/4978 [==============================] - 17s 3ms/sample - loss: 0.1653 - sparse_categorical_accuracy: 0.9566 - val_loss: 0.1615 - val_sparse_categorical_accuracy: 0.9584
# Epoch 17/50
# 4978/4978 [==============================] - 17s 3ms/sample - loss: 0.1535 - sparse_categorical_accuracy: 0.9591 - val_loss: 0.1538 - val_sparse_categorical_accuracy: 0.9601
# Epoch 18/50
# 4978/4978 [==============================] - 17s 3ms/sample - loss: 0.1449 - sparse_categorical_accuracy: 0.9608 - val_loss: 0.1422 - val_sparse_categorical_accuracy: 0.9638
# Epoch 19/50
# 4978/4978 [==============================] - 15s 3ms/sample - loss: 0.1367 - sparse_categorical_accuracy: 0.9630 - val_loss: 0.1419 - val_sparse_categorical_accuracy: 0.9634
# Epoch 20/50
# 4978/4978 [==============================] - 17s 3ms/sample - loss: 0.1295 - sparse_categorical_accuracy: 0.9646 - val_loss: 0.1360 - val_sparse_categorical_accuracy: 0.9639
# Epoch 21/50
# 4978/4978 [==============================] - 17s 3ms/sample - loss: 0.1232 - sparse_categorical_accuracy: 0.9662 - val_loss: 0.1257 - val_sparse_categorical_accuracy: 0.9672
# Epoch 22/50
# 4978/4978 [==============================] - 17s 3ms/sample - loss: 0.1161 - sparse_categorical_accuracy: 0.9683 - val_loss: 0.1215 - val_sparse_categorical_accuracy: 0.9684
# Epoch 23/50
# 4978/4978 [==============================] - 15s 3ms/sample - loss: 0.1117 - sparse_categorical_accuracy: 0.9690 - val_loss: 0.1193 - val_sparse_categorical_accuracy: 0.9682
# Epoch 24/50
# 4978/4978 [==============================] - 17s 3ms/sample - loss: 0.1083 - sparse_categorical_accuracy: 0.9698 - val_loss: 0.1176 - val_sparse_categorical_accuracy: 0.9698
# Epoch 25/50
# 4978/4978 [==============================] - 15s 3ms/sample - loss: 0.1041 - sparse_categorical_accuracy: 0.9708 - val_loss: 0.1156 - val_sparse_categorical_accuracy: 0.9697
# Epoch 26/50
# 4978/4978 [==============================] - 17s 3ms/sample - loss: 0.1010 - sparse_categorical_accuracy: 0.9715 - val_loss: 0.1123 - val_sparse_categorical_accuracy: 0.9707
# Epoch 27/50
# 4978/4978 [==============================] - 17s 3ms/sample - loss: 0.0966 - sparse_categorical_accuracy: 0.9729 - val_loss: 0.1114 - val_sparse_categorical_accuracy: 0.9711
# Epoch 28/50
# 4978/4978 [==============================] - 15s 3ms/sample - loss: 0.0935 - sparse_categorical_accuracy: 0.9736 - val_loss: 0.1125 - val_sparse_categorical_accuracy: 0.9707
# Epoch 29/50
# 4978/4978 [==============================] - 17s 3ms/sample - loss: 0.0896 - sparse_categorical_accuracy: 0.9747 - val_loss: 0.1043 - val_sparse_categorical_accuracy: 0.9734
# Epoch 30/50
# 4978/4978 [==============================] - 17s 3ms/sample - loss: 0.0845 - sparse_categorical_accuracy: 0.9764 - val_loss: 0.1038 - val_sparse_categorical_accuracy: 0.9741
# Epoch 31/50
# 4978/4978 [==============================] - 17s 3ms/sample - loss: 0.0821 - sparse_categorical_accuracy: 0.9775 - val_loss: 0.1008 - val_sparse_categorical_accuracy: 0.9756
# Epoch 32/50
# 4978/4978 [==============================] - 17s 3ms/sample - loss: 0.0772 - sparse_categorical_accuracy: 0.9784 - val_loss: 0.0972 - val_sparse_categorical_accuracy: 0.9759
# Epoch 33/50
# 4978/4978 [==============================] - 17s 3ms/sample - loss: 0.0718 - sparse_categorical_accuracy: 0.9800 - val_loss: 0.0937 - val_sparse_categorical_accuracy: 0.9780
# Epoch 34/50
# 4978/4978 [==============================] - 15s 3ms/sample - loss: 0.0682 - sparse_categorical_accuracy: 0.9810 - val_loss: 0.0944 - val_sparse_categorical_accuracy: 0.9775
# Epoch 35/50
# 4978/4978 [==============================] - 15s 3ms/sample - loss: 0.0655 - sparse_categorical_accuracy: 0.9816 - val_loss: 0.0941 - val_sparse_categorical_accuracy: 0.9778
# Epoch 36/50
# 4978/4978 [==============================] - 17s 3ms/sample - loss: 0.0631 - sparse_categorical_accuracy: 0.9822 - val_loss: 0.0903 - val_sparse_categorical_accuracy: 0.9791
# Epoch 37/50
# 4978/4978 [==============================] - 15s 3ms/sample - loss: 0.0594 - sparse_categorical_accuracy: 0.9833 - val_loss: 0.0889 - val_sparse_categorical_accuracy: 0.9788
# Epoch 38/50
# 4978/4978 [==============================] - 17s 3ms/sample - loss: 0.0577 - sparse_categorical_accuracy: 0.9836 - val_loss: 0.0896 - val_sparse_categorical_accuracy: 0.9792
# Epoch 39/50
# 4978/4978 [==============================] - 15s 3ms/sample - loss: 0.0555 - sparse_categorical_accuracy: 0.9842 - val_loss: 0.0910 - val_sparse_categorical_accuracy: 0.9788
# Epoch 40/50
# 4978/4978 [==============================] - 17s 3ms/sample - loss: 0.0545 - sparse_categorical_accuracy: 0.9842 - val_loss: 0.0863 - val_sparse_categorical_accuracy: 0.9801
# Epoch 41/50
# 4978/4978 [==============================] - 17s 3ms/sample - loss: 0.0495 - sparse_categorical_accuracy: 0.9859 - val_loss: 0.0861 - val_sparse_categorical_accuracy: 0.9806
# Epoch 42/50
# 4978/4978 [==============================] - 17s 3ms/sample - loss: 0.0484 - sparse_categorical_accuracy: 0.9860 - val_loss: 0.0846 - val_sparse_categorical_accuracy: 0.9815
# Epoch 43/50
# 4978/4978 [==============================] - 17s 3ms/sample - loss: 0.0458 - sparse_categorical_accuracy: 0.9867 - val_loss: 0.0846 - val_sparse_categorical_accuracy: 0.9818
# Epoch 44/50
# 4978/4978 [==============================] - 18s 4ms/sample - loss: 0.0419 - sparse_categorical_accuracy: 0.9878 - val_loss: 0.0798 - val_sparse_categorical_accuracy: 0.9821
# Epoch 45/50
# 4978/4978 [==============================] - 17s 3ms/sample - loss: 0.0401 - sparse_categorical_accuracy: 0.9881 - val_loss: 0.0823 - val_sparse_categorical_accuracy: 0.9823
# Epoch 46/50
# 4978/4978 [==============================] - 17s 3ms/sample - loss: 0.0374 - sparse_categorical_accuracy: 0.9887 - val_loss: 0.0832 - val_sparse_categorical_accuracy: 0.9827
# Epoch 47/50
# 4978/4978 [==============================] - 15s 3ms/sample - loss: 0.0361 - sparse_categorical_accuracy: 0.9893 - val_loss: 0.0856 - val_sparse_categorical_accuracy: 0.9818
# Epoch 48/50
# 4978/4978 [==============================] - 15s 3ms/sample - loss: 0.0344 - sparse_categorical_accuracy: 0.9898 - val_loss: 0.0855 - val_sparse_categorical_accuracy: 0.9822
# Epoch 49/50
# 4978/4978 [==============================] - 15s 3ms/sample - loss: 0.0344 - sparse_categorical_accuracy: 0.9896 - val_loss: 0.0853 - val_sparse_categorical_accuracy: 0.9827
# Epoch 50/50
# 4978/4978 [==============================] - 15s 3ms/sample - loss: 0.0308 - sparse_categorical_accuracy: 0.9907 - val_loss: 0.0841 - val_sparse_categorical_accuracy: 0.9825

# %% [markdown]
# model.load_weights(filepath='checkpoints\\ckpt_50')

# %%
def plot_training_accuracy(history):

  acc = history.history['sparse_categorical_accuracy']
  val_acc = history.history['val_sparse_categorical_accuracy']

  epochs = range(1, len(acc) + 1)

  plt.plot(epochs, acc, 'bo', label='Training accuracy')
  plt.plot(epochs, val_acc, 'r', label='Validation accuracy')
  plt.title('Training and validation accuracy')
  plt.xlabel('Epochs')
  plt.ylabel('Accuracy')
  plt.legend()

  plt.show()

plot_training_accuracy(history)

# %%
# Create the encoder model from the tensors we previously declared.
encoder_model = Model(encoder_inputs, [encoder_outputs, state_h, state_c])

# Generate a new set of tensors for our new inference decoder. Note that we are using new tensors, 
# this does not preclude using the same underlying layers that we trained on. (e.g. weights/biases).
inf_decoder_inputs = Input(shape=(None,), name="inf_decoder_inputs")
# We'll need to force feed the two state variables into the decoder each step.
state_input_h = Input(shape=(units,), name="state_input_h")
state_input_c = Input(shape=(units,), name="state_input_c")
decoder_res, decoder_h, decoder_c = decoder_lstm(
    decoder_emb(inf_decoder_inputs), 
    initial_state=[state_input_h, state_input_c])
inf_decoder_out = decoder_d2(decoder_d1(decoder_res))
inf_model = Model(inputs=[inf_decoder_inputs, state_input_h, state_input_c], 
                  outputs=[inf_decoder_out, decoder_h, decoder_c])
                  
def preprocess_query(w):
    w = w.rstrip().strip().lower()
    w = "BOS " + w + " EOS"
    return w
  
# Converts the given query (just a string) into a vector of word IDs
# using the language specified. This can be used for either the input (query)
# or target (slot)
# Output is 1-D: [timesteps/words]
def query_to_vector(query, len_input=len_input_train, t2i=t2i_train):
    pre = preprocess_query(query)
    vec = np.zeros(len_input)
    query_list = [t2i[s] for s in pre.split(' ')]
    for i,w in enumerate(query_list):
        vec[i] = w
    return vec

# Given an input string, an encoder model (infenc_model) and a decoder model (infmodel),
# return a predicted slot string.
def predict_slots(input_query, infenc_model, infmodel, 
                  len_input=len_input_train, 
                  t2i=t2i_train, s2i=s2i_train, i2s=i2s_train,
                  len_target=len_target_train,
                  attention=False):
    sent_len = len(input_query.split())
    sv = query_to_vector(input_query, len_input, t2i)
    # Reshape so we can use the encoder model. New shape=[samples,sequence length]
    sv = sv.reshape(1,len(sv))
    [emb_out, sh, sc] = infenc_model.predict(x=sv)
    
    i = 0
    start_vec = s2i["O"]
    stop_vec = s2i["O"]
    # We will continuously feed cur_vec as an input into the decoder to produce the next word,
    # which will be assigned to cur_vec. Start it with "EOS".
    cur_vec = np.zeros((1,1))
    cur_vec[0,0] = start_vec
    cur_word = "BOS"
    output_query = ""
    # Start doing the feeding. Terminate when the model predicts an "EOS" or we reach the end
    # of the max target slot length.
    while cur_word != "EOS" and i < (len_target-1) and i < sent_len+1:
        i += 1
        if cur_word != "BOS":
            output_query = output_query + " " + cur_word
        x_in = [cur_vec, sh, sc]
        # This will allow us to accomodate attention models, which we will talk about later.
        if attention:
            x_in += [emb_out]
        [nvec, sh, sc] = infmodel.predict(x=x_in)
        # The output of the model is a massive softmax vector with one spot for every possible word. Convert
        # it to a word ID using argmax().
        cur_vec[0,0] = np.argmax(nvec[0,0])
        cur_word = i2s[np.argmax(nvec[0,0])]
    return output_query
    
input_query = "what is the cheapest flight from boston to san francisco"
print(predict_slots(input_query, encoder_model, inf_model))
# Out:
# O O O B-cost_relative O O B-fromloc.city_name O B-toloc.city_name I-toloc.city_name

# %%
def evaluate_slot_filling(queries, true_slots,
                          len_input=len_input_test, 
                          t2i=t2i_test, s2i=s2i_test, i2s=i2s_test,
                          len_target=len_target_test):
  predicted_slots = []
  for q in queries:
    s = predict_slots(q, encoder_model, inf_model,
                      len_input, 
                      t2i, s2i, i2s,
                      len_target)
    predicted_slots.append(s)
  # calculate BLEU score
  print('BLEU-1: %f' % corpus_bleu(true_slots, predicted_slots, weights=(1.0, 0, 0, 0)))
  print('BLEU-2: %f' % corpus_bleu(true_slots, predicted_slots, weights=(0.5, 0.5, 0, 0)))
  print('BLEU-3: %f' % corpus_bleu(true_slots, predicted_slots, weights=(0.3, 0.3, 0.3, 0)))
  print('BLEU-4: %f' % corpus_bleu(true_slots, predicted_slots, weights=(0.25, 0.25, 0.25, 0.25)))
  
evaluate_slot_filling(query_data_test, slot_data_test)
# Out:
# BLEU-1: 0.213128
# BLEU-2: 0.000000
# BLEU-3: 0.000000
# BLEU-4: 0.000000

# %%
input_query = "list all flights from oakland to dallas after 4 pm with continental"
print(predict_slots(input_query, encoder_model, inf_model))
# Out:
# O O O O B-fromloc.city_name O B-toloc.city_name B-depart_time.time_relative B-depart_time.time I-depart_time.time B-depart_date.date_relative B-depart_date.day_name
